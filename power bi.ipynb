# %%
# Query the state_yield table
df = spark.sql("SELECT * FROM state_yield")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Query the state_yield table
df1 = spark.sql("SELECT * FROM season_performance")
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Season</th><th>avg_yield</th></tr></thead><tbody><tr><td>winter     </td><td>6.109729432894248</td></tr><tr><td>kharif     </td><td>2.260043072081102</td></tr><tr><td>rabi       </td><td>2.006970139948985</td></tr><tr><td>whole year </td><td>168.41029136381135</td></tr><tr><td>summer     </td><td>2.804769689854551</td></tr><tr><td>autumn     </td><td>2.7123165417293036</td></tr></tbody></table></div>

# %%
# %sql SHOW TABLES
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>crop_yield</td><td>false</td></tr><tr><td>default</td><td>season_performance</td><td>false</td></tr><tr><td>default</td><td>state_crop_yield</td><td>false</td></tr><tr><td>default</td><td>state_yield</td><td>false</td></tr><tr><td></td><td>_sqldf</td><td>true</td></tr></tbody></table></div>
